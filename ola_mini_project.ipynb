# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("OLA_DataSet.xlsx - July.csv")

# %%
df.head()
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3   2024-07-22 3:15:00   3:15:00  CNR2395710036  Canceled by Customer
# 4   2024-07-02 9:02:00   9:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
df.tail()
# Out:
#                        Date      Time     Booking_ID Booking_Status  \
# 103019   2024-07-31 9:06:00   9:06:00  CNR9488489435        Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100        Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233        Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035        Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721        Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# 103019   CID371654   Prime Plus      Richmond Town        Varthur  245.0
# 103020   CID334158         Auto        Vijayanagar  Richmond Town   84.0
# 103021   CID113188    Prime SUV  Bannerghatta Road       JP Nagar   35.0
# 103022   CID118301        eBike        Indiranagar    Magadi Road  210.0
# 103023   CID217959         Auto             Ulsoor         Hennur  175.0
#
#         C_TAT Canceled_Rides_by_Customer Canceled_Rides_by_Driver  \
# ...

# %%
df.shape
# Out:
# (103024, 20)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  str
#  1   Time                        103024 non-null  str
#  2   Booking_ID                  103024 non-null  str
#  3   Booking_Status              103024 non-null  str
#  4   Customer_ID                 103024 non-null  str
#  5   Vehicle_Type                103024 non-null  str
#  6   Pickup_Location             103024 non-null  str
#  7   Drop_Location               103024 non-null  str
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   str
#  11  Canceled_Rides_by_Driver    18434 non-null   str
#  12  Incomplete_Rides            63967 non-null   str
# ...

# %%
df.describe(include='all')
# Out:
#                        Date     Time     Booking_ID Booking_Status  \
# count                103024   103024         103024         103024
# unique                40214     1440         103024              4
# top     2024-07-12 12:38:00  0:53:00  CNR7153255142        Success
# freq                     10      101              1          63967
# mean                    NaN      NaN            NaN            NaN
# std                     NaN      NaN            NaN            NaN
# min                     NaN      NaN            NaN            NaN
# 25%                     NaN      NaN            NaN            NaN
# 50%                     NaN      NaN            NaN            NaN
# 75%                     NaN      NaN            NaN            NaN
# max                     NaN      NaN            NaN            NaN
#
#        Customer_ID Vehicle_Type Pickup_Location Drop_Location         V_TAT  \
# count       103024       103024          103024        103024  63967.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer    92525
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# Vehicle Images                    0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Date                           0.000000
# Time                           0.000000
# Booking_ID                     0.000000
# Booking_Status                 0.000000
# Customer_ID                    0.000000
# Vehicle_Type                   0.000000
# Pickup_Location                0.000000
# Drop_Location                  0.000000
# V_TAT                         37.910584
# C_TAT                         37.910584
# Canceled_Rides_by_Customer    89.809171
# Canceled_Rides_by_Driver      82.107082
# Incomplete_Rides              37.910584
# Incomplete_Rides_Reason       96.189237
# Booking_Value                  0.000000
# Payment_Method                37.910584
# Ride_Distance                  0.000000
# Driver_Ratings                37.910584
# Customer_Rating               37.910584
# Vehicle Images                 0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
cols = ['Booking_Value',
        'Ride_Distance',
        'Driver_Ratings',
        'Customer_Rating',
        'V_TAT',
        'C_TAT']

for col in cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
num_cols = df.select_dtypes(include=np.number).columns

df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])
# Out:
# C:\Users\shaguftha\AppData\Local\Temp\ipykernel_8272\2165584795.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include='object').columns

# %%
for col in df.columns:
    print(col)
    print(df[col].nunique())
# Out:
# Date
# 40214
# Time
# 1440
# Booking_ID
# 103024
# Booking_Status
# 4
# Customer_ID
# 94544
# Vehicle_Type
# 7
# Pickup_Location
# 50
# Drop_Location
# 50
# V_TAT
# 40
# C_TAT
# 25
# Canceled_Rides_by_Customer
# 5
# Canceled_Rides_by_Driver
# 4
# Incomplete_Rides
# 2
# Incomplete_Rides_Reason
# 3
# Booking_Value
# 2883
# Payment_Method
# 4
# Ride_Distance
# 50
# Driver_Ratings
# 21
# Customer_Rating
# 21
# Vehicle Images
# 7

# %%
obj = df.select_dtypes(include='object').columns

for col in obj:
    df[col] = df[col].str.strip().str.title()
# Out:
# C:\Users\shaguftha\AppData\Local\Temp\ipykernel_8272\312281671.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj = df.select_dtypes(include='object').columns

# %%
import matplotlib.pyplot as plt

df.boxplot(column=['Booking_Value'], rot=45, grid=True, vert=True, figsize=(10, 6))
plt.show()

# %%
def load_data(file_path):
    """
    Load data from a CSV file into a pandas DataFrame.

    Parameters:
    file_path (str): The path to the CSV file.

    Returns:
    pd.DataFrame: A DataFrame containing the loaded data.
    """
    try:
        data = pd.read_csv(file_path)
        return data
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# %%
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[us]
#  1   Time                        103024 non-null  str
#  2   Booking_ID                  103024 non-null  str
#  3   Booking_Status              103024 non-null  str
#  4   Customer_ID                 103024 non-null  str
#  5   Vehicle_Type                103024 non-null  str
#  6   Pickup_Location             103024 non-null  str
#  7   Drop_Location               103024 non-null  str
#  8   V_TAT                       103024 non-null  float64
#  9   C_TAT                       103024 non-null  float64
#  10  Canceled_Rides_by_Customer  103024 non-null  str
#  11  Canceled_Rides_by_Driver    103024 non-null  str
#  12  Incomplete_Rides            103024 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# Date                          0
# Time                          0
# Booking_ID                    0
# Booking_Status                0
# Customer_ID                   0
# Vehicle_Type                  0
# Pickup_Location               0
# Drop_Location                 0
# V_TAT                         0
# C_TAT                         0
# Canceled_Rides_by_Customer    0
# Canceled_Rides_by_Driver      0
# Incomplete_Rides              0
# Incomplete_Rides_Reason       0
# Booking_Value                 0
# Payment_Method                0
# Ride_Distance                 0
# Driver_Ratings                0
# Customer_Rating               0
# Vehicle Images                0
# dtype: int64

# %%
df.to_csv("OLA_Cleaned.csv", index=False)

# %%
df.head()
# Out:
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  Cnr7153255142    Canceled By Driver
# 1 2024-07-25 22:20:00  22:20:00  Cnr2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  Cnr2982357879               Success
# 3 2024-07-22 03:15:00   3:15:00  Cnr2395710036  Canceled By Customer
# 4 2024-07-02 09:02:00   9:02:00  Cnr1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   Cid713523  Prime Sedan     Tumkur Road      Rt Nagar  168.0   85.0
# 1   Cid225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   Cid270156    Prime Suv   Sahakar Nagar       Varthur  238.0  130.0
# 3   Cid581320        Ebike      Hsr Layout   Vijayanagar  168.0   85.0
# 4   Cid939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
df.describe(include='all')
# Out:
#                               Date     Time     Booking_ID Booking_Status  \
# count                       103024   103024         103024         103024
# unique                         NaN     1440         103024              4
# top                            NaN  0:53:00  Cnr7153255142        Success
# freq                           NaN      101              1          63967
# mean    2024-07-16 11:31:38.879678      NaN            NaN            NaN
# min            2024-07-01 00:00:00      NaN            NaN            NaN
# 25%            2024-07-08 18:41:00      NaN            NaN            NaN
# 50%            2024-07-16 11:23:00      NaN            NaN            NaN
# 75%            2024-07-24 05:18:00      NaN            NaN            NaN
# max            2024-07-31 23:58:00      NaN            NaN            NaN
# std                            NaN      NaN            NaN            NaN
#
#        Customer_ID Vehicle_Type Pickup_Location Drop_Location          V_TAT  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Optional (for better visuals)
import seaborn as sns

# %%
df['Booking_Status'].value_counts().plot(
    kind='bar',
    figsize=(8,5),
    title='Booking Status Distribution'
)

plt.xlabel("Booking Status")
plt.ylabel("Number of Rides")
plt.show()

# %%
ride_volume = df.groupby('Date').size()

ride_volume.plot(
    figsize=(20,5),
    title='Ride Volume Over Time'
)

plt.xlabel("Date")
plt.ylabel("Total Rides")
plt.show()

# %%
df['Vehicle_Type'].value_counts().plot(
    kind='bar',
    figsize=(10,5),
    title='Vehicle Type Distribution'
)

plt.xlabel("Vehicle Type")
plt.ylabel("Bookings")
plt.show()

# %%
revenue = df.groupby('Payment_Method')['Booking_Value'].sum()

revenue.plot(
    kind='bar',
    figsize=(15,5),
    title='Revenue by Payment Method'
)

plt.ylabel("Revenue")
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.hist(df['Ride_Distance'], bins=40)

plt.title("Ride Distance Distribution")
plt.xlabel("Distance")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Driver_Ratings'], bins=10)

plt.title("Driver Ratings")
plt.xlabel("Ratings")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Customer_Rating'], bins=10)

plt.title("Customer Ratings")
plt.xlabel("Ratings")
plt.ylabel("Count")

plt.show()

# %%
pickup = df['Pickup_Location'].value_counts().head(10)

pickup.plot(
    kind='bar',
    figsize=(15,5),
    title='Top Pickup Locations'
)

plt.show()

# %%
pickup = df['Drop_Location'].value_counts().head(10)

pickup.plot(
    kind='bar',
    figsize=(15,5),
    title='Top Drop Locations'
)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Booking_Value'], bins=30)

plt.title("Booking Value Distribution")
plt.xlabel("Booking Value")
plt.ylabel("Frequency")

plt.show()

# %%
numeric = df.select_dtypes(include=np.number)

corr = numeric.corr()

plt.figure(figsize=(10,8))

sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title("Correlation Matrix")

plt.show()

# %%
avg = df.groupby('Vehicle_Type')['Booking_Value'].mean()

avg.plot(
    kind='bar',
    figsize=(8,5),
    title='Average Booking Value by Vehicle'
)

plt.show()

# %%
distance = df.groupby('Vehicle_Type')['Ride_Distance'].mean()

distance.plot(
    kind='bar',
    figsize=(8,5),
    title='Average Ride Distance'
)

plt.show()

# %%
payment = df['Payment_Method'].value_counts()

payment.plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7,7)
)

plt.ylabel("")
plt.title("Payment Method Share")

plt.show()

# %%
# !pip install mysql-connector-python

# %%
import pandas as pd
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root"
)

cursor = conn.cursor()
print("Connected to MySQL database")
# Out:
# Connected to MySQL database

# %%
cursor.execute("CREATE DATABASE IF NOT EXISTS ola")
cursor.execute("USE ola")
print("Database 'ola' is ready for use.")
# Out:
# Database 'ola' is ready for use.

# %%
df = pd.read_csv("OLA_Cleaned.csv")

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS bookings (
    Date DATE,
    Time TIME,
    Booking_ID VARCHAR(30),
    Booking_Status VARCHAR(50),
    Customer_ID VARCHAR(30),
    Vehicle_Type VARCHAR(30),
    Pickup_Location VARCHAR(100),
    Drop_Location VARCHAR(100),
    V_TAT INT,
    C_TAT INT,
    Canceled_Rides_by_Customer VARCHAR(100),
    Canceled_Rides_by_Driver VARCHAR(100),
    Incomplete_Rides VARCHAR(20),
    Incomplete_Rides_Reason VARCHAR(255),
    Booking_Value DECIMAL(10,2),
    Payment_Method VARCHAR(30),
    Ride_Distance DECIMAL(10,2),
    Driver_Ratings DECIMAL(3,2),
    Customer_Rating DECIMAL(3,2),
    Vehicle_Images VARCHAR(255)
)
""")
print("Table 'bookings' is ready for use.")
# Out:
# Table 'bookings' is ready for use.

# %%
for row in df.itertuples(index=False):
    cursor.execute("""
    INSERT INTO bookings
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
    """, tuple(row))

conn.commit()

# %%
query = """
SELECT *
FROM bookings
WHERE Booking_Status='Success';
"""

pd.read_sql(query, conn)
# Out:
# C:\Users\shaguftha\AppData\Local\Temp\ipykernel_8272\3621770330.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#              Date            Time     Booking_ID Booking_Status Customer_ID  \
# 0      2024-07-25 0 days 22:20:00  Cnr2940424040        Success   Cid225428
# 1      2024-07-30 0 days 19:59:00  Cnr2982357879        Success   Cid270156
# 2      2024-07-02 0 days 09:02:00  Cnr1797421769        Success   Cid939555
# 3      2024-07-13 0 days 04:42:00  Cnr8787177882        Success   Cid802429
# 4      2024-07-23 0 days 09:51:00  Cnr3612067560        Success   Cid476071
# ...           ...             ...            ...            ...         ...
# 63962  2024-07-31 0 days 09:06:00  Cnr9488489435        Success   Cid371654
# ...

# %%
query = """
SELECT Vehicle_Type,
AVG(Ride_Distance) AS Avg_Distance
FROM bookings
GROUP BY Vehicle_Type;
"""

pd.read_sql(query, conn)
# Out:
# C:\Users\shaguftha\AppData\Local\Temp\ipykernel_8272\1304879876.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#   Vehicle_Type  Avg_Distance
# 0  Prime Sedan     15.764939
# 1         Bike     15.533079
# 2    Prime Suv     15.274514
# 3        Ebike     15.580589
# 4         Mini     15.510102
# 5   Prime Plus     15.447474
# 6         Auto      6.238089

# %%
query = """
SELECT COUNT(*) AS Customer_Cancelled
FROM bookings
WHERE Canceled_Rides_by_Customer IS NOT NULL
AND Canceled_Rides_by_Customer<>'';
"""

pd.read_sql(query, conn)
# Out:
# C:\Users\shaguftha\AppData\Local\Temp\ipykernel_8272\3375347362.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#    Customer_Cancelled
# 0              103024

# %%
query = """
SELECT COUNT(*) AS Customer_Cancelled
FROM bookings
WHERE Canceled_Rides_by_Customer IS NOT NULL
AND Canceled_Rides_by_Customer<>'';
"""

pd.read_sql(query, conn)
# Out:
# C:\Users\shaguftha\AppData\Local\Temp\ipykernel_8272\3375347362.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#    Customer_Cancelled
# 0              103024

# %%
query = """YOUR SQL QUERY HERE"""
result = pd.read_sql(query, conn)
result
# Out:
# C:\Users\shaguftha\AppData\Local\Temp\ipykernel_8272\436116180.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\shaguftha\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
# ...
